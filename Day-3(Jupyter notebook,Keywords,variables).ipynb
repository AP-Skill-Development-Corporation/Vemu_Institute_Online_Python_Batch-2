# %% [markdown]
# # Python Basics

# %% [markdown]
# # For shortcut keys
#
# click
#
# ***esc+h***

# %% [markdown]
# # Keywords or Reserve Words in Python

# %% [markdown]
# - Keywords are Reserved
# - We cannot use these keywords are as a Variable name or functions or any other
# - We have 35 keywords
# - False,True,None these three are in Capilize remaining all are in lower case

# %%
help(keyword)
# Out:
# Help on module keyword:
#
# NAME
#     keyword - Keywords (from "graminit.c")
#
# DESCRIPTION
#     This file is automatically generated; please don't muck it up!
#
#     To update the symbols in this file, 'cd' to the top directory of
#     the python source tree after building the interpreter and run:
#
#         ./python Lib/keyword.py
#
# FUNCTIONS
#     iskeyword = __contains__(...) method of builtins.frozenset instance
#         x.__contains__(y) <==> y in x.
#
# DATA
#     __all__ = ['iskeyword', 'kwlist']
#     kwlist = ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'aw...
#
# FILE
#     c:\programdata\anaconda3\lib\keyword.py

# %%
help()
# Out:
# Welcome to Python 3.7's help utility!
#
# If this is your first time using Python, you should definitely check out
# the tutorial on the Internet at https://docs.python.org/3.7/tutorial/.
#
# Enter the name of any module, keyword, or topic to get help on writing
# Python programs and using Python modules.  To quit this help utility and
# return to the interpreter, just type "quit".
#
# To get a list of available modules, keywords, symbols, or topics, type
# "modules", "keywords", "symbols", or "topics".  Each module also comes
# with a one-line summary of what it does; to list the modules whose name
# or summary contain a given string such as "spam", type "modules spam".
#
# help> break
# The "break" statement
# *********************
#
#    break_stmt ::= "break"
#
# "break" may only occur syntactically nested in a "for" or "while"
# loop, but not nested in a function or class definition within that
# loop.
#
# It terminates the nearest enclosing loop, skipping the optional "else"
# ...

# %%
import keyword
dir(keyword)
# Out:
# ['__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'iskeyword',
#  'kwlist',
#  'main']

# %%
keyword.iskeyword('is')
# Out:
# True

# %%
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
print((keyword.kwlist))
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
True

# %%
if
global
and
finally
import
in 
is
# Out:
#   File "<ipython-input-11-9d526553a371>", line 1
#     if
#       ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Comment Lines In Python
#
#
# - (#) This is a single line comment
# - (""" """      or  ''' ''') - This is for multiple lines

# %%
print("This is the print function")

# %% [markdown]
# - This is addition program

# %%
This is addition program
2+6
# Out:
#   File "<ipython-input-6-80d4e29fa54b>", line 1
#     This is addition program
#                            ^
# SyntaxError: invalid syntax

# %%
# This is addition program
# This is a comment line 
# This is comment line for single line
2+6
# Out:
# 8

# %%
""" This is a multiple comment 
line 
so I will give it the syntax """


6*7
# Out:
# 42

# %%
'''This is a multiple comment 
line 
so I will give it the syntax '''

7/9
# Out:
# 0.7777777777777778

# %% [markdown]
# # Variables
#
# - To store and assign the values
# - it is declared as a alphabets
# - Values are stored with assigning = symbol
# - variables can't assign or start numbers and any special symbols except underscore( _ )
#
#
# -

# %%
10
# Out:
# 10

# %%
a=100

# %%
a
# Out:
# 100

# %%
A
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-7d157d7c000a> in <module>
# ----> 1 A
#
# NameError: name 'A' is not defined

# %%
a
# Out:
# 100

# %%
a
# Out:
# 100

# %%
100=a
# Out:
#   File "<ipython-input-20-7802fdc14d03>", line 1
#     100=a
#          ^
# SyntaxError: can't assign to literal

# %%
@=a
# Out:
#   File "<ipython-input-21-eb647ee74c84>", line 1
#     @=a
#      ^
# SyntaxError: invalid syntax

# %%
_=9

# %%
_
# Out:
# 9

# %%
a@100=20
# Out:
#   File "<ipython-input-24-49f3519f623f>", line 1
#     a@100=20
#             ^
# SyntaxError: can't assign to operator

# %%
a100=40

# %%
a100
# Out:
# 40

# %%
a=100
b=100
c=100
d=100
e=100

# %%
c
# Out:
# 100

# %%
d
# Out:
# 100

# %% [markdown]
# e

# %%
# How to store single value in multiple variables

# %%
i=j=k=l=m=n=300

# %%
i
# Out:
# 300

# %%
j
# Out:
# 300

# %%
k
# Out:
# 300

# %%
# How to store multiple value in multiple variables in single line

# %%
a,b,c,d,e,f=10,20,30,40,50,60

# %%
a
# Out:
# 10

# %%
b
# Out:
# 20

# %%
c
# Out:
# 30

# %%
d
# Out:
# 40

# %%
e
# Out:
# 50

# %%
f
# Out:
# 60

# %%
# Different ways to declare variables

# %%
z=290

# %%
z
# Out:
# 290

# %%
name=Madhan kumar
# Out:
#   File "<ipython-input-46-73cb623e9712>", line 1
#     name=Madhan kumar
#                     ^
# SyntaxError: invalid syntax

# %% [markdown]
# # String is declared as single quote(' ') or double quote(" ")

# %%
name= " Madhan kumar"
name
# Out:
# ' Madhan kumar'

# %%
name
# Out:
# ' Madhan kumar'

# %%
z=20
i="INDIA"
b="20"
z
i
b
# Out:
# '20'

# %%
z=20
i="INDIA"
b="20"
print(z)
print(i)
print(b)
# Out:
# 20
# INDIA
# 20

# %%
example="!@#$%^&*()QWFHFTJGKODBNBMMJ<M<NMHJXCDGGHDSFDGfhfghnfjnskjgnkfjgkj1234567890"

# %%
example
# Out:
# '!@#$%^&*()QWFHFTJGKODBNBMMJ<M<NMHJXCDGGHDSFDGfhfghnfjnskjgnkfjgkj1234567890'

# %%
print(example)
# Out:
# !@#$%^&*()QWFHFTJGKODBNBMMJ<M<NMHJXCDGGHDSFDGfhfghnfjnskjgnkfjgkj1234567890

# %%
print(z,b,i)
# Out:
# 20 20 INDIA

# %%
"""this is a
multiple comment line"""
a=20
b=10
h="""this is a
multiple comment line
and it is declared
in 
a variable"""
g='this is a
multiple comment line
and it is declared
in 
a variable'
print(a)
print(b)
print("a")
print("b")
print("a+b")
print(a+b)
print("a+b+c")
print(a+b+c)
print('a+b+c+t')
# print(a+b+c+t)
print(h)
print(g)
# Out:
#   File "<ipython-input-77-afe16c46cd1f>", line 10
#     g='this is a
#                 ^
# SyntaxError: EOL while scanning string literal

# %%
"""this is a
multiple comment line"""
# Out:
# 'this is a\nmultiple comment line'

# %%
h="""this is a
multiple comment line
and it is declared
in 
a variable"""
print(h)
# Out:
# this is a
# multiple comment line
# and it is declared
# in
# a variable

# %%
g='this is a
multiple comment line
and it is declared
in 
a variable'
# Out:
#   File "<ipython-input-80-f3c10b348cf4>", line 1
#     g='this is a
#                 ^
# SyntaxError: EOL while scanning string literal
